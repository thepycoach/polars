# %%
import polars as pl

df = pl.read_csv("https://www.football-data.co.uk/mmz4281/2223/E0.csv")

# %%
root = "https://www.football-data.co.uk/mmz4281/"
    
leagues = ['E0', 'E1', 'E2', 'E3', 'EC']
frames = []
for league in leagues:
    df = pl.read_csv(root + "2223" + "/" + league + ".csv")
    frames.append(df)

# %%
frames[2]
# Out:
# shape: (443, 106)
# ┌─────┬────────────┬───────┬─────────────┬─────┬─────────┬─────────┬─────────┬─────────┐
# │ Div ┆ Date       ┆ Time  ┆ HomeTeam    ┆ ... ┆ MaxCAHH ┆ MaxCAHA ┆ AvgCAHH ┆ AvgCAHA │
# │ --- ┆ ---        ┆ ---   ┆ ---         ┆     ┆ ---     ┆ ---     ┆ ---     ┆ ---     │
# │ str ┆ str        ┆ str   ┆ str         ┆     ┆ f64     ┆ f64     ┆ f64     ┆ f64     │
# ╞═════╪════════════╪═══════╪═════════════╪═════╪═════════╪═════════╪═════════╪═════════╡
# │ E2  ┆ 30/07/2022 ┆ 15:00 ┆ Accrington  ┆ ... ┆ 2.16    ┆ 1.83    ┆ 2.06    ┆ 1.77    │
# │ E2  ┆ 30/07/2022 ┆ 15:00 ┆ Bristol Rvs ┆ ... ┆ 2.13    ┆ 1.82    ┆ 2.07    ┆ 1.76    │
# │ E2  ┆ 30/07/2022 ┆ 15:00 ┆ Cambridge   ┆ ... ┆ 1.86    ┆ 2.14    ┆ 1.78    ┆ 2.05    │
# │ E2  ┆ 30/07/2022 ┆ 15:00 ┆ Cheltenham  ┆ ... ┆ 1.98    ┆ 1.99    ┆ 1.89    ┆ 1.92    │
# │ ... ┆ ...        ┆ ...   ┆ ...         ┆ ... ┆ ...     ┆ ...     ┆ ...     ┆ ...     │
# │ E2  ┆ 18/03/2023 ┆ 15:00 ┆ Port Vale   ┆ ... ┆ 1.91    ┆ 2.05    ┆ 1.85    ┆ 1.96    │
# │ E2  ┆ 18/03/2023 ┆ 15:00 ┆ Wycombe     ┆ ... ┆ 2.04    ┆ 1.89    ┆ 1.98    ┆ 1.83    │
# │ E2  ┆ 21/03/2023 ┆ 19:45 ┆ Accrington  ┆ ... ┆ 2.08    ┆ 1.88    ┆ 1.98    ┆ 1.83    │
# │ E2  ┆ 21/03/2023 ┆ 20:00 ┆ Barnsley    ┆ ... ┆ 2.12    ┆ 1.89    ┆ 2.03    ┆ 1.79    │
# └─────┴────────────┴───────┴─────────────┴─────┴─────────┴─────────┴─────────┴─────────┘

# %%
import pandas as pd

my_list = pd.read_html("https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1%E2%80%9320)")

# %%
pandas_df = my_list[4]

# %%
pandas_df
# Out:
#     No. overall  No. in season                                         Title  \
# 0            60              1                                 "Kamp Krusty"
# 1            61              2                     "A Streetcar Named Marge"
# 2            62              3                           "Homer the Heretic"
# 3            63              4                       "Lisa the Beauty Queen"
# 4            64              5                     "Treehouse of Horror III"
# 5            65              6                 "Itchy & Scratchy: The Movie"
# 6            66              7                            "Marge Gets a Job"
# 7            67              8                        "New Kid on the Block"
# 8            68              9                                    "Mr. Plow"
# 9            69             10                           "Lisa's First Word"
# 10           70             11                       "Homer's Triple Bypass"
# 11           71             12                      "Marge vs. the Monorail"
# 12           72             13                              "Selma's Choice"
# 13           73             14                "Brother from the Same Planet"
# 14           74             15                                 "I Love Lisa"
# 15           75             16                                    "Duffless"
# 16           76             17                    "Last Exit to Springfield"
# 17           77             18  "So It's Come to This: A Simpsons Clip Show"
# 18           78             19                                   "The Front"
# 19           79             20                                "Whacking Day"
# 20           80             21                             "Marge in Chains"
# 21           81             22                       "Krusty Gets Kancelled"
#
#         Directed by                                         Written by  \
# 0     Mark Kirkland                                     David M. Stern
# 1        Rich Moore                                        Jeff Martin
# 2       Jim Reardon                                       George Meyer
# 3     Mark Kirkland                                        Jeff Martin
# 4      Carlos Baeza  Al Jean & Mike ReissJay Kogen & Wallace Woloda...
# 5        Rich Moore                                  John Swartzwelder
# 6        Jeff Lynch                       Bill Oakley & Josh Weinstein
# 7        Wes Archer                                      Conan O'Brien
# 8       Jim Reardon                                          Jon Vitti
# 9     Mark Kirkland                                        Jeff Martin
# 10  David Silverman                    Gary Apple & Michael Carrington
# 11       Rich Moore                                      Conan O'Brien
# 12     Carlos Baeza                                     David M. Stern
# 13       Jeff Lynch                                          Jon Vitti
# 14       Wes Archer                                         Frank Mula
# 15      Jim Reardon                                     David M. Stern
# 16    Mark Kirkland                     Jay Kogen & Wallace Wolodarsky
# 17     Carlos Baeza                                          Jon Vitti
# 18       Rich Moore                                    Adam I. Lapidus
# 19       Jeff Lynch                                  John Swartzwelder
# 20      Jim Reardon                       Bill Oakley & Josh Weinstein
# 21  David Silverman                                  John Swartzwelder
#
#      Original air date Prod. code U.S. viewers (millions)
# 0   September 24, 1992       8F24               21.8[104]
# 1      October 1, 1992       8F18               18.3[105]
# 2      October 8, 1992       9F01               19.3[106]
# 3     October 15, 1992       9F02               19.0[107]
# 4     October 29, 1992       9F04               25.1[108]
# 5     November 3, 1992       9F03               20.1[109]
# 6     November 5, 1992       9F05               22.9[109]
# 7    November 12, 1992       9F06               23.1[110]
# 8    November 19, 1992       9F07               24.0[111]
# 9     December 3, 1992       9F08               28.6[112]
# 10   December 17, 1992       9F09               23.6[113]
# 11    January 14, 1993       9F10               23.0[114]
# 12    January 21, 1993       9F11               24.5[115]
# 13    February 4, 1993       9F12               23.8[116]
# 14   February 11, 1993       9F13               25.2[117]
# 15   February 18, 1993       9F14               25.7[118]
# 16      March 11, 1993       9F15               22.4[119]
# 17       April 1, 1993       9F17               25.5[120]
# 18      April 15, 1993       9F16               20.1[121]
# 19      April 29, 1993       9F18               20.0[122]
# 20         May 6, 1993       9F20               17.3[123]
# 21        May 13, 1993       9F19               19.4[124]

# %%
polars_df = pl.from_pandas(pandas_df)

# %%
polars_df
# Out:
# shape: (22, 8)
# ┌───────────┬────────────┬─────────────┬───────────┬──────────┬────────────┬──────────┬────────────┐
# │ No.       ┆ No. in     ┆ Title       ┆ Directed  ┆ Written  ┆ Original   ┆ Prod.    ┆ U.S.       │
# │ overall   ┆ season     ┆ ---         ┆ by        ┆ by       ┆ air date   ┆ code     ┆ viewers    │
# │ ---       ┆ ---        ┆ str         ┆ ---       ┆ ---      ┆ ---        ┆ ---      ┆ (millions) │
# │ i64       ┆ i64        ┆             ┆ str       ┆ str      ┆ str        ┆ str      ┆ ---        │
# │           ┆            ┆             ┆           ┆          ┆            ┆          ┆ str        │
# ╞═══════════╪════════════╪═════════════╪═══════════╪══════════╪════════════╪══════════╪════════════╡
# │ 60        ┆ 1          ┆ "Kamp       ┆ Mark      ┆ David M. ┆ September  ┆ 8F24     ┆ 21.8[104]  │
# │           ┆            ┆ Krusty"     ┆ Kirkland  ┆ Stern    ┆ 24, 1992   ┆          ┆            │
# │ 61        ┆ 2          ┆ "A          ┆ Rich      ┆ Jeff     ┆ October 1, ┆ 8F18     ┆ 18.3[105]  │
# │           ┆            ┆ Streetcar   ┆ Moore     ┆ Martin   ┆  1992      ┆          ┆            │
# │           ┆            ┆ Named       ┆           ┆          ┆            ┆          ┆            │
# │           ┆            ┆ Marge"      ┆           ┆          ┆            ┆          ┆            │
# │ 62        ┆ 3          ┆ "Homer the  ┆ Jim       ┆ George   ┆ October 8, ┆ 9F01     ┆ 19.3[106]  │
# │           ┆            ┆ Heretic"    ┆ Reardon   ┆ Meyer    ┆  1992      ┆          ┆            │
# │ 63        ┆ 4          ┆ "Lisa the   ┆ Mark      ┆ Jeff     ┆ October 15 ┆ 9F02     ┆ 19.0[107]  │
# │           ┆            ┆ Beauty      ┆ Kirkland  ┆ Martin   ┆ , 1992     ┆          ┆            │
# │           ┆            ┆ Queen"      ┆           ┆          ┆            ┆          ┆            │
# │ ...       ┆ ...        ┆ ...         ┆ ...       ┆ ...      ┆ ...        ┆ ...      ┆ ...        │
# │ 78        ┆ 19         ┆ "The Front" ┆ Rich      ┆ Adam I.  ┆ April 15,  ┆ 9F16     ┆ 20.1[121]  │
# │           ┆            ┆             ┆ Moore     ┆ Lapidus  ┆ 1993       ┆          ┆            │
# │ 79        ┆ 20         ┆ "Whacking   ┆ Jeff      ┆ John Swa ┆ April 29,  ┆ 9F18     ┆ 20.0[122]  │
# │           ┆            ┆ Day"        ┆ Lynch     ┆ rtzwelde ┆ 1993       ┆          ┆            │
# │           ┆            ┆             ┆           ┆ r        ┆            ┆          ┆            │
# │ 80        ┆ 21         ┆ "Marge in   ┆ Jim       ┆ Bill     ┆ May 6, 199 ┆ 9F20     ┆ 17.3[123]  │
# │           ┆            ┆ Chains"     ┆ Reardon   ┆ Oakley & ┆ 3          ┆          ┆            │
# │           ┆            ┆             ┆           ┆ Josh Wei ┆            ┆          ┆            │
# │           ┆            ┆             ┆           ┆ nstein   ┆            ┆          ┆            │
# │ 81        ┆ 22         ┆ "Krusty     ┆ David     ┆ John Swa ┆ May 13, 19 ┆ 9F19     ┆ 19.4[124]  │
# │           ┆            ┆ Gets        ┆ Silverman ┆ rtzwelde ┆ 93         ┆          ┆            │
# │           ┆            ┆ Kancelled"  ┆           ┆ r        ┆            ┆          ┆            │
# └───────────┴────────────┴─────────────┴───────────┴──────────┴────────────┴──────────┴────────────┘

# %%
my_new_list = [pl.from_pandas(pandas_df) for pandas_df in my_list]

# %%
my_new_list[4]
# Out:
# shape: (22, 8)
# ┌───────────┬────────────┬─────────────┬───────────┬──────────┬────────────┬──────────┬────────────┐
# │ No.       ┆ No. in     ┆ Title       ┆ Directed  ┆ Written  ┆ Original   ┆ Prod.    ┆ U.S.       │
# │ overall   ┆ season     ┆ ---         ┆ by        ┆ by       ┆ air date   ┆ code     ┆ viewers    │
# │ ---       ┆ ---        ┆ str         ┆ ---       ┆ ---      ┆ ---        ┆ ---      ┆ (millions) │
# │ i64       ┆ i64        ┆             ┆ str       ┆ str      ┆ str        ┆ str      ┆ ---        │
# │           ┆            ┆             ┆           ┆          ┆            ┆          ┆ str        │
# ╞═══════════╪════════════╪═════════════╪═══════════╪══════════╪════════════╪══════════╪════════════╡
# │ 60        ┆ 1          ┆ "Kamp       ┆ Mark      ┆ David M. ┆ September  ┆ 8F24     ┆ 21.8[104]  │
# │           ┆            ┆ Krusty"     ┆ Kirkland  ┆ Stern    ┆ 24, 1992   ┆          ┆            │
# │ 61        ┆ 2          ┆ "A          ┆ Rich      ┆ Jeff     ┆ October 1, ┆ 8F18     ┆ 18.3[105]  │
# │           ┆            ┆ Streetcar   ┆ Moore     ┆ Martin   ┆  1992      ┆          ┆            │
# │           ┆            ┆ Named       ┆           ┆          ┆            ┆          ┆            │
# │           ┆            ┆ Marge"      ┆           ┆          ┆            ┆          ┆            │
# │ 62        ┆ 3          ┆ "Homer the  ┆ Jim       ┆ George   ┆ October 8, ┆ 9F01     ┆ 19.3[106]  │
# │           ┆            ┆ Heretic"    ┆ Reardon   ┆ Meyer    ┆  1992      ┆          ┆            │
# │ 63        ┆ 4          ┆ "Lisa the   ┆ Mark      ┆ Jeff     ┆ October 15 ┆ 9F02     ┆ 19.0[107]  │
# │           ┆            ┆ Beauty      ┆ Kirkland  ┆ Martin   ┆ , 1992     ┆          ┆            │
# │           ┆            ┆ Queen"      ┆           ┆          ┆            ┆          ┆            │
# │ ...       ┆ ...        ┆ ...         ┆ ...       ┆ ...      ┆ ...        ┆ ...      ┆ ...        │
# │ 78        ┆ 19         ┆ "The Front" ┆ Rich      ┆ Adam I.  ┆ April 15,  ┆ 9F16     ┆ 20.1[121]  │
# │           ┆            ┆             ┆ Moore     ┆ Lapidus  ┆ 1993       ┆          ┆            │
# │ 79        ┆ 20         ┆ "Whacking   ┆ Jeff      ┆ John Swa ┆ April 29,  ┆ 9F18     ┆ 20.0[122]  │
# │           ┆            ┆ Day"        ┆ Lynch     ┆ rtzwelde ┆ 1993       ┆          ┆            │
# │           ┆            ┆             ┆           ┆ r        ┆            ┆          ┆            │
# │ 80        ┆ 21         ┆ "Marge in   ┆ Jim       ┆ Bill     ┆ May 6, 199 ┆ 9F20     ┆ 17.3[123]  │
# │           ┆            ┆ Chains"     ┆ Reardon   ┆ Oakley & ┆ 3          ┆          ┆            │
# │           ┆            ┆             ┆           ┆ Josh Wei ┆            ┆          ┆            │
# │           ┆            ┆             ┆           ┆ nstein   ┆            ┆          ┆            │
# │ 81        ┆ 22         ┆ "Krusty     ┆ David     ┆ John Swa ┆ May 13, 19 ┆ 9F19     ┆ 19.4[124]  │
# │           ┆            ┆ Gets        ┆ Silverman ┆ rtzwelde ┆ 93         ┆          ┆            │
# │           ┆            ┆ Kancelled"  ┆           ┆ r        ┆            ┆          ┆            │
# └───────────┴────────────┴─────────────┴───────────┴──────────┴────────────┴──────────┴────────────┘
